# %% [markdown]
# # Pre-requisites

# %%
# Set PROJECT_PATH to the parent folder of this notebook (assumes notebook is run from its repo root).
from pathlib import Path
import os
# Use current working directory as the project path; adjust if you run the notebook from a different cwd.
project_path = str(Path.cwd())
os.environ['PROJECT_PATH'] = project_path
print('PROJECT_PATH set to', project_path)
# Out:
# PROJECT_PATH set to c:\Users\mathias\Work\Projects\the-project\sample-api-with-db

# %%
# !pip install -r requirements.txt
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
import os
from pathlib import Path

# Add the scripts folder to sys.path so we can import helpers
scripts_path = str(Path(os.environ.get('PROJECT_PATH', '.')).resolve() / 'scripts')
if scripts_path not in sys.path:
    sys.path.insert(0, scripts_path)

# Import the helper functions from scripts/helpers.py
from helpers import start_in_new_terminal, open_url_when_ready

print(f'Imported helpers from {scripts_path}')
# Out:
# Imported helpers from C:\Users\mathias\Work\Projects\the-project\sample-api-with-db\scripts

# %% [markdown]
# # Prepare the database

# %%
# !alembic upgrade 0001
# Out:
# INFO  [alembic.runtime.migration] Context impl PostgresqlImpl.
# INFO  [alembic.runtime.migration] Will assume transactional DDL.
# INFO  [alembic.runtime.migration] Running upgrade  -> 0000, create users table
# INFO  [alembic.runtime.migration] Running upgrade 0000 -> 0001, create users table

# %%
# !alembic upgrade 0003
# Out:
# INFO  [alembic.runtime.migration] Context impl PostgresqlImpl.
# INFO  [alembic.runtime.migration] Will assume transactional DDL.
# INFO  [alembic.runtime.migration] Running upgrade  -> 0000, create users table
# INFO  [alembic.runtime.migration] Running upgrade 0000 -> 0001, create users table

# %% [markdown]
# # Start the API

# %%
# Start the API using Flask
start_in_new_terminal([sys.executable, '-m', 'backend.app'], title='FlaskServer', log_file='server.log', cwd=os.environ.get('PROJECT_PATH'))

# %%
# Open the Swagger UI in a browser
open_url_when_ready('http://localhost:5000/docs-restx', timeout=30)
